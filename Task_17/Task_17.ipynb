# %% [markdown]
# ### Task 17

# %% [markdown]
# ##### Subplots

# %% [markdown]
# Generate a Figure with 2x2 Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Customizing sub plots

# %%
x = np.linspace(0, 90, 900)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = x**2
data = np.random.randn(1000)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# %% [markdown]
# Line plot

# %%
axs[0, 0].plot(x, y1, 'r')
axs[0, 0].set_title('Line Plot')
axs[0, 0].set_xlabel('X-axis')
axs[0, 0].set_ylabel('Y-axis')
# Out:
# Text(4.444444444444452, 0.5, 'Y-axis')

# %% [markdown]
# Scatter Plot

# %%
axs[0, 1].scatter(x, y2, c='b', marker='x')
axs[0, 1].set_title('Scatter Plot')
axs[0, 1].set_xlabel('X-axis')
axs[0, 1].set_ylabel('Y-axis')
# Out:
# Text(427.1717171717171, 0.5, 'Y-axis')

# %% [markdown]
# Bar Plot

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 3, 8, 4]
axs[1, 0].bar(categories, values, color='g')
axs[1, 0].set_title('Bar Plot')
axs[1, 0].set_xlabel('Categories')
axs[1, 0].set_ylabel('Values')
# Out:
# Text(4.444444444444452, 0.5, 'Values')

# %% [markdown]
# Histogram

# %%
axs[1, 1].hist(data, bins=30, color='purple')
axs[1, 1].set_title('Histogram')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('Frequency')
# Out:
# Text(427.1717171717171, 0.5, 'Frequency')

# %%
plt.tight_layout()

# %% [markdown]
# Creating Histogram

# %%
data = np.random.randn(1000)

# %%
plt.hist(data, bins=20, color='blue', edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Plot Multiple Histograms on the Same Figure

# %%
data1 = np.random.randn(1000)
data2 = np.random.randn(1000) + 1

# %%
plt.hist(data1, bins=20, alpha=0.5, label='Dataset 1', color='blue', edgecolor='black')
plt.hist(data2, bins=20, alpha=0.5, label='Dataset 2', color='red', edgecolor='black')
plt.title('Multiple Histograms')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# Normalize histograms

# %%
plt.hist(data1, bins=20, alpha=0.5, label='Dataset 1', color='blue', edgecolor='black', density=True)
plt.hist(data2, bins=20, alpha=0.5, label='Dataset 2', color='red', edgecolor='black', density=True)
plt.title('Normalized Histograms')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# Box Plot

# %%
data = np.random.randn(100)

# %%
plt.boxplot(data)
plt.title('Box Plot')
plt.xlabel('Dataset')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# Generate Multiple Box Plots

# %%
data1 = np.random.randn(100)
data2 = np.random.randn(100) + 1  
data3 = np.random.randn(100) - 1

# %%
plt.boxplot([data1, data2, data3], labels=['Dataset 1', 'Dataset 2', 'Dataset 3'])
plt.title('Multiple Box Plots')
plt.xlabel('Dataset')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# Customizing Box Plot

# %%
box = plt.boxplot([data1, data2, data3], patch_artist=True, labels=['Dataset 1', 'Dataset 2', 'Dataset 3'])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data1 = np.random.randn(100)
data2 = np.random.randn(100) + 1
data3 = np.random.randn(100) - 1

# %%
fig, ax = plt.subplots(figsize=(10, 6))

box = ax.boxplot([data1, data2, data3], patch_artist=True, labels=['Dataset 1', 'Dataset 2', 'Dataset 3'])

colors = ['red', 'lightgreen', 'lightblue']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_edgecolor('black')

# Customize whiskers, caps, medians, and fliers
for whisker in box['whiskers']:
    whisker.set(color='black', linewidth=1.5)
for cap in box['caps']:
    cap.set(color='black', linewidth=1.5)
for median in box['medians']:
    median.set(color='black', linewidth=1.5)
for flier in box['fliers']:
    flier.set(marker='o', color='black', alpha=0.5)

# Adding title and labels
ax.set_title('Customized Box Plots')
ax.set_xlabel('Dataset')
ax.set_ylabel('Value')

# Show plot
plt.show()
